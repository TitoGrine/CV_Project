# %%
from google.colab import drive, files

drive.mount('/content/drive')

# %% [markdown]
# Upload the Kaggle keys in order to be able to download the datasets.

# %%
files.upload()

# !pip install --upgrade pip
# !pip install kaggle==1.5.6
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json

# %% [markdown]
# ### Download Datasets

# %% [markdown]
# Download [Kaggle dataset of Hotel images](https://www.kaggle.com/c/hotel-id-2021-fgvc8/data) to Google Drive.

# %%
# !kaggle competitions download -c hotel-id-2021-fgvc8 -p '/content/drive/MyDrive/Colab Notebooks/Computer Vision/Project/dataset/'

# %% [markdown]
# Download [Kaggle dataset of human silhouettes](https://www.kaggle.com/deepshah16/silhouettes-of-human-posture) to Google Drive.

# %%
# !kaggle datasets download -d deepshah16/silhouettes-of-human-posture -p '/content/drive/MyDrive/Colab Notebooks/Computer Vision/Project/dataset/silhouettes'

# %% [markdown]
# ### Unzip the datasets.

# %%
import os

root_path = '/content/drive/MyDrive/Colab Notebooks/Computer Vision/Project/dataset/'

os.chdir(root_path)

# %% [markdown]
# You may need to run the `unzip` command 2-3 times since disk space is limited in Google Colab, therefore it can run out of memory before every file is unzipped.

# %%
# !unzip -n hotel-id-2021-fgvc8.zip

# %%
# !unzip -q silhouettes-of-human-posture.zip
